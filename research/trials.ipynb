# %%
d = {"key":"value","key1":"value1"}

# %%
d['key']
# Out:
# 'value'

# %%
d.key
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 d.key
#
# AttributeError: 'dict' object has no attribute 'key'

# %%
from box import ConfigBox

# %%
d2 = {"key":"value","key1":"value1"}

# %%
d2 = ConfigBox(d2)

# %%
d2.key
# Out:
# 'value'

# %% [markdown]
# ## Download data from google drive

# %%
import gdown

# %%
url = "https://drive.google.com/file/d/192gc2ugmsSonUTeVLJ_iI6LF5Epe6TFZ/view?usp=drive_link"

# %%
file_id = url.split("/")[-2]

# %%
file_id
# Out:
# '192gc2ugmsSonUTeVLJ_iI6LF5Epe6TFZ'

# %%
prefix = 'https://drive.google.com/uc?/export=download&id='
gdown.download(prefix + file_id, "Chest-CT-scan_DATA.zip")
# Out:
# Downloading...
# From (original): https://drive.google.com/uc?id=192gc2ugmsSonUTeVLJ_iI6LF5Epe6TFZ
# From (redirected): https://drive.google.com/uc?id=192gc2ugmsSonUTeVLJ_iI6LF5Epe6TFZ&confirm=t&uuid=7f3deb6b-2106-483a-a7f0-731a6fafde67
# To: c:\Users\KIIT0001\Desktop\Chest-cancer-classification\research\Chest-CT-scan_DATA.zip
# 100%|██████████| 49.0M/49.0M [00:13<00:00, 3.66MB/s]
# 'Chest-CT-scan_DATA.zip'
